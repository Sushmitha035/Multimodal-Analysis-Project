# %%
import os
import csv
import time
import requests
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager

def setup_driver():
    """Set up a Selenium WebDriver with a manually specified driver."""
    options = webdriver.ChromeOptions()
    options.add_argument("--headless")  # Run in headless mode
    options.add_argument("--disable-gpu")
    options.add_argument("--no-sandbox")

    # Manually specify ChromeDriver path (update if needed)
    driver_path = "C:/Users/Sushmitha/Downloads/multimodal/task1/chromedriver.exe"
    service = Service(driver_path)
    
    driver = webdriver.Chrome(service=service, options=options)
    return driver

def fetch_and_download_images(driver, query, num_images=50, dataset_path="RandomVision-50"):
    """Fetch image URLs from Bing Search and download them."""
    search_url = f"https://www.bing.com/images/search?q={query}&form=HDRSC2"
    driver.get(search_url)
    time.sleep(2)  # Allow images to load

    images = driver.find_elements(By.CSS_SELECTOR, "img.mimg")
    category_folder = os.path.join(dataset_path, query.replace(" ", "_"))
    os.makedirs(category_folder, exist_ok=True)
    
    metadata = []
    for i, img in enumerate(images[:num_images]):
        src = img.get_attribute("src")
        if src and "http" in src:
            try:
                response = requests.get(src, stream=True, timeout=5)
                if response.status_code == 200:
                    filename = f"{query.replace(' ', '')}{i}.jpg"
                    filepath = os.path.join(category_folder, filename)
                    with open(filepath, 'wb') as file:
                        file.write(response.content)
                    metadata.append([src, filename])
            except Exception as e:
                print(f"Error downloading {src}: {e}")
    return metadata

def save_metadata(metadata, dataset_path="RandomVision-50"):
    """Save metadata (image URLs and filenames) to a CSV file."""
    csv_file = os.path.join(dataset_path, "metadata.csv")
    with open(csv_file, 'w', newline='') as file:
        writer = csv.writer(file)
        writer.writerow(["Image URL", "Filename"])
        writer.writerows(metadata)

def main():
    categories = [
        "Mountain Landscapes", "Space Nebulas", "City Skylines", "Wildlife Photography", "Colorful Birds",
        "Underwater Creatures", "Ancient Ruins", "Futuristic Cars", "Robotic Technology", "Abstract Art",
        "Street Graffiti", "Luxury Yachts", "Traditional Dances", "Fireworks Displays", "Hot Air Balloons",
        "Historical Castles", "Deep Sea Diving", "Golden Sunsets", "Extreme Sports", "Forest Waterfalls"
    ]
    
    dataset_path = "RandomVision-50"
    os.makedirs(dataset_path, exist_ok=True)
    
    driver = setup_driver()
    all_metadata = []

    for category in categories:
        print(f"Downloading images for {category}...")
        metadata = fetch_and_download_images(driver, category, dataset_path=dataset_path)
        all_metadata.extend(metadata)

    save_metadata(all_metadata, dataset_path)
    driver.quit()
    print("Dataset collection completed!")

if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\Sushmitha\Downloads\multimodal\task1\.venv\Lib\site-packages\selenium\webdriver\common\driver_finder.py:64, in DriverFinder._binary_paths(self)
#      63 if not Path(path).is_file():
# ---> 64     raise ValueError(f"The path is not a valid file: {path}")
#      65 self._paths["driver_path"] = path
#
# ValueError: The path is not a valid file: C:/Users/Sushmitha/Downloads/multimodal/task1/chromedriver.exe
#
# The above exception was the direct cause of the following exception:
#
# NoSuchDriverException                     Traceback (most recent call last)
# Cell In[14], line 82
#      79     print("Dataset collection completed!")
#      81 if __name__ == "__main__":
# ---> 82     main()
#
# Cell In[14], line 69, in main()
#      66 dataset_path = "RandomVision-50"
#      67 os.makedirs(dataset_path, exist_ok=True)
# ---> 69 driver = setup_driver()
#      70 all_metadata = []
#      72 for category in categories:
#
# Cell In[14], line 21, in setup_driver()
#      18 driver_path = "C:/Users/Sushmitha/Downloads/multimodal/task1/chromedriver.exe"
#      19 service = Service(driver_path)
# ---> 21 driver = webdriver.Chrome(service=service, options=options)
#      22 return driver
#
# File c:\Users\Sushmitha\Downloads\multimodal\task1\.venv\Lib\site-packages\selenium\webdriver\chrome\webdriver.py:45, in WebDriver.__init__(self, options, service, keep_alive)
#      42 service = service if service else Service()
#      43 options = options if options else Options()
# ---> 45 super().__init__(
#      46     browser_name=DesiredCapabilities.CHROME["browserName"],
#      47     vendor_prefix="goog",
#      48     options=options,
#      49     service=service,
#      50     keep_alive=keep_alive,
#      51 )
#
# File c:\Users\Sushmitha\Downloads\multimodal\task1\.venv\Lib\site-packages\selenium\webdriver\chromium\webdriver.py:50, in ChromiumDriver.__init__(self, browser_name, vendor_prefix, options, service, keep_alive)
#      47 self.service = service
#      49 finder = DriverFinder(self.service, options)
# ---> 50 if finder.get_browser_path():
#      51     options.binary_location = finder.get_browser_path()
#      52     options.browser_version = None
#
# File c:\Users\Sushmitha\Downloads\multimodal\task1\.venv\Lib\site-packages\selenium\webdriver\common\driver_finder.py:47, in DriverFinder.get_browser_path(self)
#      46 def get_browser_path(self) -> str:
# ---> 47     return self._binary_paths()["browser_path"]
#
# File c:\Users\Sushmitha\Downloads\multimodal\task1\.venv\Lib\site-packages\selenium\webdriver\common\driver_finder.py:78, in DriverFinder._binary_paths(self)
#      76 except Exception as err:
#      77     msg = f"Unable to obtain driver for {browser}"
# ---> 78     raise NoSuchDriverException(msg) from err
#      79 return self._paths
#
# NoSuchDriverException: Message: Unable to obtain driver for chrome; For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors/driver_location

# %%
pip install requests
# Out:
# Collecting requests
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting charset-normalizer<4,>=2 (from requests)
#   Downloading charset_normalizer-3.4.1-cp312-cp312-win_amd64.whl.metadata (36 kB)
# Collecting idna<4,>=2.5 (from requests)
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests)
#   Using cached urllib3-2.3.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests)
#   Using cached certifi-2025.1.31-py3-none-any.whl.metadata (2.5 kB)
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Using cached certifi-2025.1.31-py3-none-any.whl (166 kB)
# Downloading charset_normalizer-3.4.1-cp312-cp312-win_amd64.whl (102 kB)
# Using cached idna-3.10-py3-none-any.whl (70 kB)
# Using cached urllib3-2.3.0-py3-none-any.whl (128 kB)
# Installing collected packages: urllib3, idna, charset-normalizer, certifi, requests
# Successfully installed certifi-2025.1.31 charset-normalizer-3.4.1 idna-3.10 requests-2.32.3 urllib3-2.3.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install selenium
# Out:
# Collecting selenium
#   Using cached selenium-4.29.0-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\sushmitha\downloads\multimodal\task1\.venv\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (2.3.0)
# Collecting trio~=0.17 (from selenium)
#   Using cached trio-0.29.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting trio-websocket~=0.9 (from selenium)
#   Using cached trio_websocket-0.12.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\sushmitha\downloads\multimodal\task1\.venv\lib\site-packages (from selenium) (2025.1.31)
# Collecting typing_extensions~=4.9 (from selenium)
#   Using cached typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Collecting websocket-client~=1.8 (from selenium)
#   Using cached websocket_client-1.8.0-py3-none-any.whl.metadata (8.0 kB)
# Collecting attrs>=23.2.0 (from trio~=0.17->selenium)
#   Downloading attrs-25.3.0-py3-none-any.whl.metadata (10 kB)
# Collecting sortedcontainers (from trio~=0.17->selenium)
#   Using cached sortedcontainers-2.4.0-py2.py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: idna in c:\users\sushmitha\downloads\multimodal\task1\.venv\lib\site-packages (from trio~=0.17->selenium) (3.10)
# Collecting outcome (from trio~=0.17->selenium)
#   Using cached outcome-1.3.0.post0-py2.py3-none-any.whl.metadata (2.6 kB)
# Collecting sniffio>=1.3.0 (from trio~=0.17->selenium)
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting cffi>=1.14 (from trio~=0.17->selenium)
#   Using cached cffi-1.17.1-cp312-cp312-win_amd64.whl.metadata (1.6 kB)
# Collecting wsproto>=0.14 (from trio-websocket~=0.9->selenium)
#   Using cached wsproto-1.2.0-py3-none-any.whl.metadata (5.6 kB)
# Collecting pysocks!=1.5.7,<2.0,>=1.5.6 (from urllib3[socks]<3,>=1.26->selenium)
#   Using cached PySocks-1.7.1-py3-none-any.whl.metadata (13 kB)
# Collecting pycparser (from cffi>=1.14->trio~=0.17->selenium)
#   Using cached pycparser-2.22-py3-none-any.whl.metadata (943 bytes)
# Collecting h11<1,>=0.9.0 (from wsproto>=0.14->trio-websocket~=0.9->selenium)
#   Using cached h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Using cached selenium-4.29.0-py3-none-any.whl (9.5 MB)
# Using cached trio-0.29.0-py3-none-any.whl (492 kB)
# Using cached trio_websocket-0.12.2-py3-none-any.whl (21 kB)
# Using cached typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Using cached websocket_client-1.8.0-py3-none-any.whl (58 kB)
# Downloading attrs-25.3.0-py3-none-any.whl (63 kB)
# Using cached cffi-1.17.1-cp312-cp312-win_amd64.whl (181 kB)
# Using cached outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Using cached PySocks-1.7.1-py3-none-any.whl (16 kB)
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Using cached wsproto-1.2.0-py3-none-any.whl (24 kB)
# Using cached sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
# Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# Using cached pycparser-2.22-py3-none-any.whl (117 kB)
# Installing collected packages: sortedcontainers, websocket-client, typing_extensions, sniffio, pysocks, pycparser, h11, attrs, wsproto, outcome, cffi, trio, trio-websocket, selenium
# Successfully installed attrs-25.3.0 cffi-1.17.1 h11-0.14.0 outcome-1.3.0.post0 pycparser-2.22 pysocks-1.7.1 selenium-4.29.0 sniffio-1.3.1 sortedcontainers-2.4.0 trio-0.29.0 trio-websocket-0.12.2 typing_extensions-4.12.2 websocket-client-1.8.0 wsproto-1.2.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install webdriver_manager
# Out:
# Collecting webdriver_manager
#   Using cached webdriver_manager-4.0.2-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: requests in c:\users\sushmitha\downloads\multimodal\task1\.venv\lib\site-packages (from webdriver_manager) (2.32.3)
# Collecting python-dotenv (from webdriver_manager)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: packaging in c:\users\sushmitha\downloads\multimodal\task1\.venv\lib\site-packages (from webdriver_manager) (24.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sushmitha\downloads\multimodal\task1\.venv\lib\site-packages (from requests->webdriver_manager) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sushmitha\downloads\multimodal\task1\.venv\lib\site-packages (from requests->webdriver_manager) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sushmitha\downloads\multimodal\task1\.venv\lib\site-packages (from requests->webdriver_manager) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sushmitha\downloads\multimodal\task1\.venv\lib\site-packages (from requests->webdriver_manager) (2025.1.31)
# Using cached webdriver_manager-4.0.2-py2.py3-none-any.whl (27 kB)
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Installing collected packages: python-dotenv, webdriver_manager
# Successfully installed python-dotenv-1.0.1 webdriver_manager-4.0.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import csv
import time
import requests
from bs4 import BeautifulSoup

# Define search categories (tourist places)
categories = [
    "Eiffel Tower France", "Great Wall of China", "Machu Picchu Peru", "Statue of Liberty USA", "Colosseum Italy",
    "Taj Mahal India", "Christ the Redeemer Brazil", "Sydney Opera House Australia", "Santorini Greece", "Grand Canyon USA",
    "Mount Fuji Japan", "Niagara Falls Canada", "Pyramids of Giza Egypt", "Petra Jordan", "Big Ben London",
    "Burj Khalifa Dubai", "Times Square New York", "Great Barrier Reef Australia", "Northern Lights Norway", "Banff National Park Canada"
]

# Create dataset folder
dataset_path = "TouristPlaces-50"
os.makedirs(dataset_path, exist_ok=True)

def fetch_image_urls(query, num_images=50):
    """Scrape Bing Image Search for image URLs."""
    search_url = f"https://www.bing.com/images/search?q={query.replace(' ', '+')}&form=HDRSC2"
    headers = {"User-Agent": "Mozilla/5.0"}
    
    response = requests.get(search_url, headers=headers)
    response.raise_for_status()

    soup = BeautifulSoup(response.text, "html.parser")
    image_elements = soup.find_all("img")

    image_urls = []
    for img in image_elements:
        src = img.get("src")
        if src and src.startswith("http"):
            image_urls.append(src)
        if len(image_urls) >= num_images:
            break

    return image_urls

def download_images(query, image_urls):
    """Download images from URLs and save them in categorized folders."""
    category_folder = os.path.join(dataset_path, query.replace(" ", "_"))
    os.makedirs(category_folder, exist_ok=True)
    
    metadata = []
    for i, img_url in enumerate(image_urls):
        try:
            response = requests.get(img_url, stream=True, timeout=5)
            if response.status_code == 200:
                filename = f"{query.replace(' ', '')}{i}.jpg"
                filepath = os.path.join(category_folder, filename)
                
                with open(filepath, "wb") as file:
                    file.write(response.content)
                
                metadata.append([query, img_url, filename])
                print(f"Downloaded: {filename}")
        except Exception as e:
            print(f"Error downloading {img_url}: {e}")
    
    return metadata

# Start the scraping and downloading process
all_metadata = []
for category in categories:
    print(f"Fetching images for: {category}...")
    image_urls = fetch_image_urls(category)
    metadata = download_images(category, image_urls)
    all_metadata.extend(metadata)

# Save metadata to CSV
csv_file = os.path.join(dataset_path, "metadata.csv")
with open(csv_file, "w", newline="", encoding="utf-8") as file:
    writer = csv.writer(file)
    writer.writerow(["Category", "Image URL", "Filename"])
    writer.writerows(all_metadata)

print("✅ Image scraping and downloading completed!")
# Out:
# Fetching images for: Eiffel Tower France...
# Error downloading https://tse2.mm.bing.net/th?q=Tour+Eiffel+Paris+France&w=42&h=42&c=7&rs=1&p=0&o=5&pid=1.7&mkt=en-IN&cc=IN&setlang=en&adlt=moderate&t=1: HTTPSConnectionPool(host='tse2.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://tse4.mm.bing.net/th?q=Eiffel+Tower+in+Paris+France&w=42&h=42&c=7&rs=1&p=0&o=5&pid=1.7&mkt=en-IN&cc=IN&setlang=en&adlt=moderate&t=1: HTTPSConnectionPool(host='tse4.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://tse4.mm.bing.net/th?q=Eiffel+Tower+in+Night&w=42&h=42&c=7&rs=1&p=0&o=5&pid=1.7&mkt=en-IN&cc=IN&setlang=en&adlt=moderate&t=1: HTTPSConnectionPool(host='tse4.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Downloaded: EiffelTowerFrance3.jpg
# Error downloading https://tse4.mm.bing.net/th?q=Climbing+Eiffel+Tower&w=42&h=42&c=7&rs=1&p=0&o=5&pid=1.7&mkt=en-IN&cc=IN&setlang=en&adlt=moderate&t=1: HTTPSConnectionPool(host='tse4.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://tse4.mm.bing.net/th/id/OIP.P7eYP2gK7SXHIR6gLqZmZgHaFj?w=194&h=145&c=7&r=0&o=5&pid=1.7: HTTPSConnectionPool(host='tse4.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Downloaded: EiffelTowerFrance6.jpg
# Error downloading https://tse4.mm.bing.net/th/id/OIP.MU3kLSG68pJOe5Se5z5UwAHaFj?w=64&h=64&c=1&rs=1&qlt=90&r=0&pid=InlineBlock: HTTPSConnectionPool(host='tse4.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Downloaded: EiffelTowerFrance8.jpg
# Error downloading https://tse2.mm.bing.net/th/id/OIP.RVzlEZ7XZ-Oay3mwQgunIAHaFj?w=194&h=146&c=7&r=0&o=5&pid=1.7: HTTPSConnectionPool(host='tse2.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Downloaded: EiffelTowerFrance10.jpg
# Error downloading https://tse2.mm.bing.net/th?q=Picture+of+Train+Tour+of+France+by+the+Eiffel+Tower&w=178&h=68&c=1&rs=1&pid=InlineBlock&mkt=en-IN&cc=IN&setlang=en&adlt=moderate&t=1: HTTPSConnectionPool(host='tse2.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://tse4.mm.bing.net/th?q=Little+Einsteins+France+Eiffel+Tower&w=178&h=68&c=1&rs=1&pid=InlineBlock&mkt=en-IN&cc=IN&setlang=en&adlt=moderate&t=1: HTTPSConnectionPool(host='tse4.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://tse3.mm.bing.net/th?q=Eiffel+Tower+France+Beautiful+in+Rectangle&w=178&h=68&c=1&rs=1&pid=InlineBlock&mkt=en-IN&cc=IN&setlang=en&adlt=moderate&t=1: HTTPSConnectionPool(host='tse3.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://tse3.mm.bing.net/th/id/OIP.6Mg1drRs6xiHrzdOsonHmQHaE8?w=194&h=129&c=7&r=0&o=5&pid=1.7: HTTPSConnectionPool(host='tse3.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://tse2.mm.bing.net/th/id/OIP.vHPJUXmFVo4KmhaOQ-ZuywHaE7?w=194&h=129&c=7&r=0&o=5&pid=1.7: HTTPSConnectionPool(host='tse2.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Downloaded: EiffelTowerFrance16.jpg
# Error downloading https://tse2.mm.bing.net/th/id/OIP.rbZSHSWqh-2i8vuYHO5BagHaJH?w=194&h=239&c=7&r=0&o=5&pid=1.7: HTTPSConnectionPool(host='tse2.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://tse1.mm.bing.net/th/id/OIP.NGZZ1U48qik_eP-zzE1hBgHaKP?w=194&h=268&c=7&r=0&o=5&pid=1.7: HTTPSConnectionPool(host='tse1.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Downloaded: EiffelTowerFrance19.jpg
# Error downloading https://tse2.mm.bing.net/th/id/OIP.TiVt89e_nUT_HcvQRwwRIwHaFj?w=194&h=146&c=7&r=0&o=5&pid=1.7: HTTPSConnectionPool(host='tse2.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Downloaded: EiffelTowerFrance21.jpg
# Downloaded: EiffelTowerFrance22.jpg
# Downloaded: EiffelTowerFrance23.jpg
# Downloaded: EiffelTowerFrance24.jpg
# Error downloading https://tse2.mm.bing.net/th/id/OIP.uJg1lGxR_nMGq8wiaA2ofQHaJ4?w=64&h=64&c=1&rs=1&qlt=90&r=0&pid=InlineBlock: HTTPSConnectionPool(host='tse2.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://tse2.mm.bing.net/th/id/OIP.x9eAe9efkNDXgiE8UXjomwHaLH?w=64&h=64&c=1&rs=1&qlt=90&r=0&pid=InlineBlock: HTTPSConnectionPool(host='tse2.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Fetching images for: Great Wall of China...
# Error downloading https://tse2.mm.bing.net/th?q=Great+Wall+of+China+in+Winter&w=42&h=42&c=7&rs=1&p=0&o=5&pid=1.7&mkt=en-IN&cc=IN&setlang=en&adlt=moderate&t=1: HTTPSConnectionPool(host='tse2.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Downloaded: GreatWallofChina1.jpg
# Downloaded: GreatWallofChina2.jpg
# Error downloading https://tse2.mm.bing.net/th?q=Great+Wall+of+China+Entrance&w=42&h=42&c=7&rs=1&p=0&o=5&pid=1.7&mkt=en-IN&cc=IN&setlang=en&adlt=moderate&t=1: HTTPSConnectionPool(host='tse2.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://tse2.mm.bing.net/th/id/OIGP.MjwHiEAqFJSjTDbYe0dc?w=228&h=228&c=6&o=5&pid=1.7: HTTPSConnectionPool(host='tse2.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://tse2.mm.bing.net/th/id/OIP.CPY_O4GURZewfa_XPRO9swHaLH?w=115&h=180&c=7&r=0&o=5&pid=1.7: HTTPSConnectionPool(host='tse2.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Downloaded: GreatWallofChina6.jpg
# Downloaded: GreatWallofChina7.jpg
# Downloaded: GreatWallofChina8.jpg
# Downloaded: GreatWallofChina9.jpg
# Error downloading https://tse2.mm.bing.net/th/id/OIP.oYF4WAxEngHmX9iWXPF-IwAAAA?w=173&h=197&c=7&r=0&o=5&pid=1.7: HTTPSConnectionPool(host='tse2.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://tse2.mm.bing.net/th/id/OIP.9V1tg0HBSg59_gbRN0rrbwHaE7?w=295&h=197&c=7&r=0&o=5&pid=1.7: HTTPSConnectionPool(host='tse2.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://tse3.mm.bing.net/th/id/OIP.h_O2cbon3PCriFN2O2xIPQHaE8?w=266&h=180&c=7&r=0&o=5&pid=1.7: HTTPSConnectionPool(host='tse3.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Downloaded: GreatWallofChina13.jpg
# Error downloading https://tse1.mm.bing.net/th/id/OIP.-jO5v0JhOAHNFaON5pQdWwHaF2?w=193&h=180&c=7&r=0&o=5&pid=1.7: HTTPSConnectionPool(host='tse1.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Downloaded: GreatWallofChina15.jpg
# Error downloading https://tse1.mm.bing.net/th/id/OIP.VcKMGGoorn8TPtTjzVvFcwHaK5?w=89&h=90&c=1&rs=1&qlt=90&r=0&pid=InlineBlock: HTTPSConnectionPool(host='tse1.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://tse1.mm.bing.net/th/id/OIP.k-k0dLiSNgJhW7oMG6VJLAHaE8?w=266&h=180&c=7&r=0&o=5&pid=1.7: HTTPSConnectionPool(host='tse1.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Fetching images for: Machu Picchu Peru...
# Downloaded: MachuPicchuPeru0.jpg
# Error downloading https://tse3.mm.bing.net/th?q=Inca+Trail+to+Machu+Picchu+Peru&w=42&h=42&c=7&rs=1&p=0&o=5&pid=1.7&mkt=en-IN&cc=IN&setlang=en&adlt=moderate&t=1: HTTPSConnectionPool(host='tse3.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Downloaded: MachuPicchuPeru2.jpg
# Downloaded: MachuPicchuPeru3.jpg
# Downloaded: MachuPicchuPeru4.jpg
# Downloaded: MachuPicchuPeru5.jpg
# Downloaded: MachuPicchuPeru6.jpg
# Downloaded: MachuPicchuPeru7.jpg
# Downloaded: MachuPicchuPeru8.jpg
# Downloaded: MachuPicchuPeru9.jpg
# Downloaded: MachuPicchuPeru10.jpg
# Downloaded: MachuPicchuPeru11.jpg
# Downloaded: MachuPicchuPeru12.jpg
# Downloaded: MachuPicchuPeru13.jpg
# Downloaded: MachuPicchuPeru14.jpg
# Downloaded: MachuPicchuPeru15.jpg
# Downloaded: MachuPicchuPeru16.jpg
# Downloaded: MachuPicchuPeru17.jpg
# Downloaded: MachuPicchuPeru18.jpg
# Downloaded: MachuPicchuPeru19.jpg
# Fetching images for: Statue of Liberty USA...
# Downloaded: StatueofLibertyUSA0.jpg
# Downloaded: StatueofLibertyUSA1.jpg
# Downloaded: StatueofLibertyUSA2.jpg
# Downloaded: StatueofLibertyUSA3.jpg
# Downloaded: StatueofLibertyUSA4.jpg
# Downloaded: StatueofLibertyUSA5.jpg
# Downloaded: StatueofLibertyUSA6.jpg
# Downloaded: StatueofLibertyUSA7.jpg
# Downloaded: StatueofLibertyUSA8.jpg
# Downloaded: StatueofLibertyUSA9.jpg
# Downloaded: StatueofLibertyUSA10.jpg
# Downloaded: StatueofLibertyUSA11.jpg
# Downloaded: StatueofLibertyUSA12.jpg
# Downloaded: StatueofLibertyUSA13.jpg
# Downloaded: StatueofLibertyUSA14.jpg
# Downloaded: StatueofLibertyUSA15.jpg
# Downloaded: StatueofLibertyUSA16.jpg
# Downloaded: StatueofLibertyUSA17.jpg
# Downloaded: StatueofLibertyUSA18.jpg
# Downloaded: StatueofLibertyUSA19.jpg
# Downloaded: StatueofLibertyUSA20.jpg
# Downloaded: StatueofLibertyUSA21.jpg
# Downloaded: StatueofLibertyUSA22.jpg
# Downloaded: StatueofLibertyUSA23.jpg
# Downloaded: StatueofLibertyUSA24.jpg
# Downloaded: StatueofLibertyUSA25.jpg
# Downloaded: StatueofLibertyUSA26.jpg
# Downloaded: StatueofLibertyUSA27.jpg
# Downloaded: StatueofLibertyUSA28.jpg
# Downloaded: StatueofLibertyUSA29.jpg
# Downloaded: StatueofLibertyUSA30.jpg
# Downloaded: StatueofLibertyUSA31.jpg
# Downloaded: StatueofLibertyUSA32.jpg
# Downloaded: StatueofLibertyUSA33.jpg
# Downloaded: StatueofLibertyUSA34.jpg
# Downloaded: StatueofLibertyUSA35.jpg
# Downloaded: StatueofLibertyUSA36.jpg
# Downloaded: StatueofLibertyUSA37.jpg
# Downloaded: StatueofLibertyUSA38.jpg
# Downloaded: StatueofLibertyUSA39.jpg
# Downloaded: StatueofLibertyUSA40.jpg
# Downloaded: StatueofLibertyUSA41.jpg
# Downloaded: StatueofLibertyUSA42.jpg
# Downloaded: StatueofLibertyUSA43.jpg
# Downloaded: StatueofLibertyUSA44.jpg
# Downloaded: StatueofLibertyUSA45.jpg
# Downloaded: StatueofLibertyUSA46.jpg
# Downloaded: StatueofLibertyUSA47.jpg
# Downloaded: StatueofLibertyUSA48.jpg
# Downloaded: StatueofLibertyUSA49.jpg
# Fetching images for: Colosseum Italy...
# Downloaded: ColosseumItaly0.jpg
# Downloaded: ColosseumItaly1.jpg
# Downloaded: ColosseumItaly2.jpg
# Downloaded: ColosseumItaly3.jpg
# Downloaded: ColosseumItaly4.jpg
# Downloaded: ColosseumItaly5.jpg
# Downloaded: ColosseumItaly6.jpg
# Downloaded: ColosseumItaly7.jpg
# Downloaded: ColosseumItaly8.jpg
# Downloaded: ColosseumItaly9.jpg
# Downloaded: ColosseumItaly10.jpg
# Downloaded: ColosseumItaly11.jpg
# Error downloading https://tse4.mm.bing.net/th/id/OIP.267mO5uaCCfgmSP4y5_2WwHaEe?w=234&h=180&c=7&r=0&o=5&pid=1.7: HTTPSConnectionPool(host='tse4.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Downloaded: ColosseumItaly13.jpg
# Downloaded: ColosseumItaly14.jpg
# Downloaded: ColosseumItaly15.jpg
# Downloaded: ColosseumItaly16.jpg
# Downloaded: ColosseumItaly17.jpg
# Downloaded: ColosseumItaly18.jpg
# Error downloading https://tse1.mm.bing.net/th/id/OIP.xUTai80iiUbVOYLrXi4qpwHaEK?w=264&h=180&c=7&r=0&o=5&pid=1.7: HTTPSConnectionPool(host='tse1.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://tse1.mm.bing.net/th/id/OIP.Sa8RLxejEotGvl9JVQZ1ZwHaE8?w=222&h=180&c=7&r=0&o=5&pid=1.7: HTTPSConnectionPool(host='tse1.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Downloaded: ColosseumItaly21.jpg
# Fetching images for: Taj Mahal India...
# Error downloading https://tse1.mm.bing.net/th?q=Image+of+Taj+Mahal&w=42&h=42&c=7&rs=1&p=0&o=5&pid=1.7&mkt=en-IN&cc=IN&setlang=en&adlt=moderate&t=1: HTTPSConnectionPool(host='tse1.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://tse4.mm.bing.net/th?q=Taj+Mahal+Marble&w=42&h=42&c=7&rs=1&p=0&o=5&pid=1.7&mkt=en-IN&cc=IN&setlang=en&adlt=moderate&t=1: HTTPSConnectionPool(host='tse4.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Downloaded: TajMahalIndia2.jpg
# Error downloading https://tse4.mm.bing.net/th?q=Taj+Mahal+Tourists&w=42&h=42&c=7&rs=1&p=0&o=5&pid=1.7&mkt=en-IN&cc=IN&setlang=en&adlt=moderate&t=1: HTTPSConnectionPool(host='tse4.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://tse1.mm.bing.net/th?q=Taj+Mahal+Map&w=42&h=42&c=7&rs=1&p=0&o=5&pid=1.7&mkt=en-IN&cc=IN&setlang=en&adlt=moderate&t=1: HTTPSConnectionPool(host='tse1.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://tse1.mm.bing.net/th?q=Taj+Mahal+Tour&w=42&h=42&c=7&rs=1&p=0&o=5&pid=1.7&mkt=en-IN&cc=IN&setlang=en&adlt=moderate&t=1: HTTPSConnectionPool(host='tse1.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://tse1.mm.bing.net/th/id/ORA4.1BAE58E933D03D4C452B7BAC0A8B0EAA_4D95E8927ADFA27E?w=200&h=150&o=5&pid=Alab: HTTPSConnectionPool(host='tse1.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Downloaded: TajMahalIndia7.jpg
# Downloaded: TajMahalIndia8.jpg
# Downloaded: TajMahalIndia9.jpg
# Error downloading https://tse4.mm.bing.net/th/id/ORA4.D3A02524B6598B557D7258FE2326ACDD_11CFBA11E31EA122?w=200&h=150&o=5&pid=Alab: HTTPSConnectionPool(host='tse4.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://tse4.mm.bing.net/th/id/ORA4.1EE864D21F0007CD60B978491C827C4F_26CB1D30428D6C12?w=200&h=150&o=5&pid=Alab: HTTPSConnectionPool(host='tse4.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Downloaded: TajMahalIndia12.jpg
# Error downloading https://tse2.mm.bing.net/th/id/ORA4.56E8CD177B3597D99BC8494CECDA4751_7017DAC70A252300?w=200&h=150&o=5&pid=Alab: HTTPSConnectionPool(host='tse2.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://tse1.mm.bing.net/th/id/ORA4.4C34551BB9F9041CBCDFD75D0AE5B75C_EA67E13001F39400?w=200&h=150&o=5&pid=Alab: HTTPSConnectionPool(host='tse1.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Downloaded: TajMahalIndia15.jpg
# Error downloading https://tse1.mm.bing.net/th/id/ORA4.9DF53DCB15B3EDCAAF4C324605ED10CF_088DE55410414306?w=200&h=150&o=5&pid=Alab: HTTPSConnectionPool(host='tse1.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Downloaded: TajMahalIndia17.jpg
# Downloaded: TajMahalIndia18.jpg
# Downloaded: TajMahalIndia19.jpg
# Downloaded: TajMahalIndia20.jpg
# Downloaded: TajMahalIndia21.jpg
# Downloaded: TajMahalIndia22.jpg
# Downloaded: TajMahalIndia23.jpg
# Downloaded: TajMahalIndia24.jpg
# Error downloading https://tse1.mm.bing.net/th/id/OIP.uHqClJqJGX2kvnECFJ-r2wHaFC?w=275&h=187&c=7&r=0&o=5&pid=1.7: HTTPSConnectionPool(host='tse1.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://tse1.mm.bing.net/th/id/OIP.mK02DLF7aFujuBRaBS_DhQAAAA?w=186&h=187&c=7&r=0&o=5&pid=1.7: HTTPSConnectionPool(host='tse1.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://tse1.mm.bing.net/th/id/OIP.PUHQMJZ_u9fiMlv8QkrjYwHaHa?w=186&h=187&c=7&r=0&o=5&pid=1.7: HTTPSConnectionPool(host='tse1.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://tse1.mm.bing.net/th/id/OIP.H6ruzBkXSIZ_ILemcgIVAQHaFj?w=208&h=180&c=7&r=0&o=5&pid=1.7: HTTPSConnectionPool(host='tse1.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://tse1.mm.bing.net/th/id/OIP.KFCr7pV3tLTp-4zj1oA_bAAAAA?w=115&h=180&c=7&r=0&o=5&pid=1.7: HTTPSConnectionPool(host='tse1.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://tse1.mm.bing.net/th/id/OIP.ayZ76h0Iag9Sdb84vchmgQHaE8?w=234&h=180&c=7&r=0&o=5&pid=1.7: HTTPSConnectionPool(host='tse1.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://tse3.mm.bing.net/th/id/OIP.OPcvVcplENyyn3vRGUqFEwHaEx?w=242&h=180&c=7&r=0&o=5&pid=1.7: HTTPSConnectionPool(host='tse3.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Downloaded: TajMahalIndia32.jpg
# Downloaded: TajMahalIndia33.jpg
# Error downloading https://ts3.mm.bing.net/th?id=OIP.h6mMiVUkMgsXq50ZnIjGwgHaHa&pid=15.1: HTTPSConnectionPool(host='ts3.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://ts3.mm.bing.net/th?id=OIP.rv4YtDowFJSUSd3F2Ld_CQHaEJ&pid=15.1: HTTPSConnectionPool(host='ts3.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://ts2.mm.bing.net/th?id=OIP.Cl7JjUjvVKxbZ08_qBYS7QHaLH&pid=15.1: HTTPSConnectionPool(host='ts2.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://ts2.mm.bing.net/th?id=OIP.bU_jAV0yvyrgdgvF-7I9GQAAAA&pid=15.1: HTTPSConnectionPool(host='ts2.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Downloaded: TajMahalIndia38.jpg
# Error downloading https://ts2.mm.bing.net/th?id=OIP.5FFq2jGlQTcEICsMbJfd9gHaE8&pid=15.1: HTTPSConnectionPool(host='ts2.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://ts1.mm.bing.net/th?id=OIP.VPAkcbBDJelMU-0lB1yIHAHaFj&pid=15.1: HTTPSConnectionPool(host='ts1.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://ts1.mm.bing.net/th?id=OIP.WKMoL1VMYJLD6eqpf-psWAHaHa&pid=15.1: HTTPSConnectionPool(host='ts1.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Downloaded: TajMahalIndia42.jpg
# Downloaded: TajMahalIndia43.jpg
# Downloaded: TajMahalIndia44.jpg
# Downloaded: TajMahalIndia45.jpg
# Downloaded: TajMahalIndia46.jpg
# Error downloading https://ts2.mm.bing.net/th?id=OIP.Fh-H9b3z1KR8yYFPOhdL_QHaE8&pid=15.1: HTTPSConnectionPool(host='ts2.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://ts2.mm.bing.net/th?id=OIP.tWJQ7Qg6VVtH7VvnOiTf1gHaEK&pid=15.1: HTTPSConnectionPool(host='ts2.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Downloaded: TajMahalIndia49.jpg
# Fetching images for: Christ the Redeemer Brazil...
# Downloaded: ChristtheRedeemerBrazil0.jpg
# Downloaded: ChristtheRedeemerBrazil1.jpg
# Downloaded: ChristtheRedeemerBrazil2.jpg
# Downloaded: ChristtheRedeemerBrazil3.jpg
# Downloaded: ChristtheRedeemerBrazil4.jpg
# Downloaded: ChristtheRedeemerBrazil5.jpg
# Error downloading https://tse4.mm.bing.net/th/id/OIP.sZ3TjA27Ptv1VKjmb8FvcgHaHI?w=171&h=180&c=7&r=0&o=5&pid=1.7: HTTPSConnectionPool(host='tse4.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Downloaded: ChristtheRedeemerBrazil7.jpg
# Downloaded: ChristtheRedeemerBrazil8.jpg
# Downloaded: ChristtheRedeemerBrazil9.jpg
# Error downloading https://tse4.mm.bing.net/th/id/OIP.t0qYCBorrjlwtzLae8_p8gHaEJ?w=309&h=180&c=7&r=0&o=5&pid=1.7: HTTPSConnectionPool(host='tse4.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://tse4.mm.bing.net/th/id/OIP.YFayDmgrCyfwGabTYjCaqAHaEJ?w=309&h=180&c=7&r=0&o=5&pid=1.7: HTTPSConnectionPool(host='tse4.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Downloaded: ChristtheRedeemerBrazil12.jpg
# Downloaded: ChristtheRedeemerBrazil13.jpg
# Downloaded: ChristtheRedeemerBrazil14.jpg
# Downloaded: ChristtheRedeemerBrazil15.jpg
# Error downloading https://ts2.mm.bing.net/th?id=OIP.kGI9a5pNYPvOT5A0q3WumwHaE8&pid=15.1: HTTPSConnectionPool(host='ts2.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Downloaded: ChristtheRedeemerBrazil17.jpg
# Downloaded: ChristtheRedeemerBrazil18.jpg
# Downloaded: ChristtheRedeemerBrazil19.jpg
# Downloaded: ChristtheRedeemerBrazil20.jpg
# Downloaded: ChristtheRedeemerBrazil21.jpg
# Downloaded: ChristtheRedeemerBrazil22.jpg
# Downloaded: ChristtheRedeemerBrazil23.jpg
# Downloaded: ChristtheRedeemerBrazil24.jpg
# Downloaded: ChristtheRedeemerBrazil25.jpg
# Downloaded: ChristtheRedeemerBrazil26.jpg
# Downloaded: ChristtheRedeemerBrazil27.jpg
# Downloaded: ChristtheRedeemerBrazil28.jpg
# Downloaded: ChristtheRedeemerBrazil29.jpg
# Downloaded: ChristtheRedeemerBrazil30.jpg
# Downloaded: ChristtheRedeemerBrazil31.jpg
# Downloaded: ChristtheRedeemerBrazil32.jpg
# Downloaded: ChristtheRedeemerBrazil33.jpg
# Downloaded: ChristtheRedeemerBrazil34.jpg
# Downloaded: ChristtheRedeemerBrazil35.jpg
# Downloaded: ChristtheRedeemerBrazil36.jpg
# Downloaded: ChristtheRedeemerBrazil37.jpg
# Downloaded: ChristtheRedeemerBrazil38.jpg
# Downloaded: ChristtheRedeemerBrazil39.jpg
# Downloaded: ChristtheRedeemerBrazil40.jpg
# Downloaded: ChristtheRedeemerBrazil41.jpg
# Error downloading https://ts4.explicit.bing.net/th?id=OIP.Zs1BknyHla1C2Rh_QSJ7uwHaJQ&pid=15.1: HTTPSConnectionPool(host='ts4.explicit.bing.net', port=443): Max retries exceeded with url: /th?id=OIP.Zs1BknyHla1C2Rh_QSJ7uwHaJQ&pid=15.1 (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate in certificate chain (_ssl.c:1000)')))
# Downloaded: ChristtheRedeemerBrazil43.jpg
# Downloaded: ChristtheRedeemerBrazil44.jpg
# Downloaded: ChristtheRedeemerBrazil45.jpg
# Downloaded: ChristtheRedeemerBrazil46.jpg
# Downloaded: ChristtheRedeemerBrazil47.jpg
# Downloaded: ChristtheRedeemerBrazil48.jpg
# Downloaded: ChristtheRedeemerBrazil49.jpg
# Fetching images for: Sydney Opera House Australia...
# Error downloading https://tse4.mm.bing.net/th?q=Location+of+Sydney+Opera+House&w=42&h=42&c=7&rs=1&p=0&o=5&pid=1.7&mkt=en-IN&cc=IN&setlang=en&adlt=moderate&t=1: HTTPSConnectionPool(host='tse4.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://tse4.mm.bing.net/th?q=Sydney+Opera+House+Fireworks&w=42&h=42&c=7&rs=1&p=0&o=5&pid=1.7&mkt=en-IN&cc=IN&setlang=en&adlt=moderate&t=1: HTTPSConnectionPool(host='tse4.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://tse2.mm.bing.net/th?q=Photos+of+Sydney+Opera+House&w=42&h=42&c=7&rs=1&p=0&o=5&pid=1.7&mkt=en-IN&cc=IN&setlang=en&adlt=moderate&t=1: HTTPSConnectionPool(host='tse2.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Downloaded: SydneyOperaHouseAustralia3.jpg
# Error downloading https://tse2.mm.bing.net/th/id/OIP._Vl5cY9NusC1XRM6KE62xAHaE8?w=216&h=180&c=7&r=0&o=5&pid=1.7: HTTPSConnectionPool(host='tse2.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Downloaded: SydneyOperaHouseAustralia5.jpg
# Downloaded: SydneyOperaHouseAustralia6.jpg
# Downloaded: SydneyOperaHouseAustralia7.jpg
# Downloaded: SydneyOperaHouseAustralia8.jpg
# Downloaded: SydneyOperaHouseAustralia9.jpg
# Downloaded: SydneyOperaHouseAustralia10.jpg
# Error downloading https://tse2.mm.bing.net/th/id/OIP.64h0RUjl8SrkWJPHXSu78wHaFj?w=241&h=180&c=7&r=0&o=5&pid=1.7: HTTPSConnectionPool(host='tse2.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Downloaded: SydneyOperaHouseAustralia12.jpg
# Downloaded: SydneyOperaHouseAustralia13.jpg
# Error downloading https://tse2.mm.bing.net/th/id/OIP.NYERZzLRrbgAaKdMp9oMegHaFj?w=89&h=89&c=1&rs=1&qlt=90&r=0&pid=InlineBlock: HTTPSConnectionPool(host='tse2.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://tse2.mm.bing.net/th/id/OIP.1S_F7EcByXbVT2aR7bpLgAHaBc?w=89&h=90&c=1&rs=1&qlt=90&r=0&pid=InlineBlock: HTTPSConnectionPool(host='tse2.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Downloaded: SydneyOperaHouseAustralia16.jpg
# Downloaded: SydneyOperaHouseAustralia17.jpg
# Downloaded: SydneyOperaHouseAustralia18.jpg
# Downloaded: SydneyOperaHouseAustralia19.jpg
# Error downloading https://ts2.mm.bing.net/th?id=OIP.v6DoJYCo2xUoNGtnZZomDwHaFK&pid=15.1: HTTPSConnectionPool(host='ts2.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://ts4.mm.bing.net/th?id=OIP.17uesS4RUr77LOoDAKTUhwHaE9&pid=15.1: HTTPSConnectionPool(host='ts4.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Downloaded: SydneyOperaHouseAustralia22.jpg
# Error downloading https://ts4.mm.bing.net/th?id=OIP.fvV3yafSKrpjeJ8hNwfQgwHaE8&pid=15.1: HTTPSConnectionPool(host='ts4.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Downloaded: SydneyOperaHouseAustralia24.jpg
# Downloaded: SydneyOperaHouseAustralia25.jpg
# Error downloading https://ts4.mm.bing.net/th?id=OIP.Gapbn0m3wjodKShtcYrObwHaE7&pid=15.1: HTTPSConnectionPool(host='ts4.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Downloaded: SydneyOperaHouseAustralia27.jpg
# Error downloading https://ts4.mm.bing.net/th?id=OIP._yb5Z2CN6Hs9e2clWs-XbAHaE8&pid=15.1: HTTPSConnectionPool(host='ts4.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://ts4.mm.bing.net/th?id=OIP.UHb7h7ohLj3j3ILaR1qiBAHaFa&pid=15.1: HTTPSConnectionPool(host='ts4.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://ts2.mm.bing.net/th?id=OIP.eZij5CS6Pl1YFQfH0ss2BwHaHa&pid=15.1: HTTPSConnectionPool(host='ts2.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://ts4.explicit.bing.net/th?id=OIP.hFQpLYAXOOZWIx7A871N2QHaDj&pid=15.1: HTTPSConnectionPool(host='ts4.explicit.bing.net', port=443): Max retries exceeded with url: /th?id=OIP.hFQpLYAXOOZWIx7A871N2QHaDj&pid=15.1 (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate in certificate chain (_ssl.c:1000)')))
# Error downloading https://ts4.mm.bing.net/th?id=OIP.AS2M_Ob29M4rMb-pl31WIgHaEa&pid=15.1: HTTPSConnectionPool(host='ts4.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://ts2.mm.bing.net/th?id=OIP.mqoIJDBuBMCJJpyf9WcsAgHaE7&pid=15.1: HTTPSConnectionPool(host='ts2.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Downloaded: SydneyOperaHouseAustralia34.jpg
# Downloaded: SydneyOperaHouseAustralia35.jpg
# Error downloading https://ts2.mm.bing.net/th?id=OIP.GSfQ6uzFyb_Gv8BLnQGfoQHaEK&pid=15.1: HTTPSConnectionPool(host='ts2.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Downloaded: SydneyOperaHouseAustralia37.jpg
# Error downloading https://ts1.mm.bing.net/th?id=OIP.HlnOGcImk3K73UPmX8YE6AHaE8&pid=15.1: HTTPSConnectionPool(host='ts1.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://ts1.mm.bing.net/th?id=OIP.XUh4nc46in1N4zFZUUJWOgHaGL&pid=15.1: HTTPSConnectionPool(host='ts1.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Downloaded: SydneyOperaHouseAustralia40.jpg
# Error downloading https://ts1.mm.bing.net/th?id=OIP.KyhgfYST4Kc41yPqgA-5FwHaE8&pid=15.1: HTTPSConnectionPool(host='ts1.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Downloaded: SydneyOperaHouseAustralia42.jpg
# Error downloading https://ts1.mm.bing.net/th?id=OIP.FBhVLtdZ5oxwhCL4HGsf_gHaEK&pid=15.1: HTTPSConnectionPool(host='ts1.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://ts4.mm.bing.net/th?id=OIP.5ZEtEPypW_gHrsL7VDtTSwAAAA&pid=15.1: HTTPSConnectionPool(host='ts4.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://ts4.mm.bing.net/th?id=OIP.Nq-mSpHdcjdeWWT5ewBtcQHaEK&pid=15.1: HTTPSConnectionPool(host='ts4.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Downloaded: SydneyOperaHouseAustralia46.jpg
# Downloaded: SydneyOperaHouseAustralia47.jpg
# Error downloading https://ts1.mm.bing.net/th?id=OIP.5nyh9U5sq2NiUHL2naym5QHaFj&pid=15.1: HTTPSConnectionPool(host='ts1.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://ts4.mm.bing.net/th?id=OIP.meWPJAMHXDMfTbGEmQfPaQHaFc&pid=15.1: HTTPSConnectionPool(host='ts4.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Fetching images for: Santorini Greece...
# Error downloading https://tse4.mm.bing.net/th?q=Santorini+Greece+Cruise+Ship&w=42&h=42&c=7&rs=1&p=0&o=5&pid=1.7&mkt=en-IN&cc=IN&setlang=en&adlt=moderate&t=1: HTTPSConnectionPool(host='tse4.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Downloaded: SantoriniGreece1.jpg
# Downloaded: SantoriniGreece2.jpg
# Error downloading https://tse1.mm.bing.net/th?q=Things+to+See+in+Santorini+Greece&w=42&h=42&c=7&rs=1&p=0&o=5&pid=1.7&mkt=en-IN&cc=IN&setlang=en&adlt=moderate&t=1: HTTPSConnectionPool(host='tse1.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://tse1.mm.bing.net/th/id/OIGP.y4NVO7r0Up7mw84j8vlF?w=228&h=228&c=6&o=5&pid=1.7: HTTPSConnectionPool(host='tse1.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Downloaded: SantoriniGreece5.jpg
# Downloaded: SantoriniGreece6.jpg
# Error downloading https://tse1.mm.bing.net/th/id/OIP.NzYeohPZkBz7sSzjFaTSywHaE7?w=89&h=90&c=1&rs=1&qlt=90&r=0&pid=InlineBlock: HTTPSConnectionPool(host='tse1.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Downloaded: SantoriniGreece8.jpg
# Error downloading https://tse1.mm.bing.net/th/id/OIP.FD9WaZRDg9PnTkF-2MXCpAHaE8?w=177&h=180&c=7&r=0&o=5&pid=1.7: HTTPSConnectionPool(host='tse1.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Downloaded: SantoriniGreece10.jpg
# Downloaded: SantoriniGreece11.jpg
# Error downloading https://tse1.mm.bing.net/th/id/OIP.CamCUcbsCGSHw1t3D3y6KgHaE7?w=253&h=180&c=7&r=0&o=5&pid=1.7: HTTPSConnectionPool(host='tse1.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Downloaded: SantoriniGreece13.jpg
# Downloaded: SantoriniGreece14.jpg
# Downloaded: SantoriniGreece15.jpg
# Downloaded: SantoriniGreece16.jpg
# Downloaded: SantoriniGreece17.jpg
# Downloaded: SantoriniGreece18.jpg
# Downloaded: SantoriniGreece19.jpg
# Error downloading https://ts3.mm.bing.net/th?id=OIP.wMMtXqLVRsrz0U3p0PUqcQHaFD&pid=15.1: HTTPSConnectionPool(host='ts3.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://ts1.mm.bing.net/th?id=OIP.EADi9N0NHwTD8f6zKUAT8wHaE7&pid=15.1: HTTPSConnectionPool(host='ts1.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://ts3.mm.bing.net/th?id=OIP.bR4vqOIm1c41fq2X0SMsUwHaJo&pid=15.1: HTTPSConnectionPool(host='ts3.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Downloaded: SantoriniGreece23.jpg
# Error downloading https://ts3.mm.bing.net/th?id=OIP.ebsiea2mEgHgSpyk63dobwHaE8&pid=15.1: HTTPSConnectionPool(host='ts3.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Downloaded: SantoriniGreece25.jpg
# Downloaded: SantoriniGreece26.jpg
# Error downloading https://ts1.mm.bing.net/th?id=OIP.8okY0riA5l89z4nHh1ls3AHaHp&pid=15.1: HTTPSConnectionPool(host='ts1.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://ts4.mm.bing.net/th?id=OIP.gvlQ9e1A3CO9Q_3ADzGYBgHaFj&pid=15.1: HTTPSConnectionPool(host='ts4.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Downloaded: SantoriniGreece29.jpg
# Downloaded: SantoriniGreece30.jpg
# Error downloading https://ts4.mm.bing.net/th?id=OIP.DZZRcquIaGgk6QJ7w5VkVAHaDs&pid=15.1: HTTPSConnectionPool(host='ts4.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Downloaded: SantoriniGreece32.jpg
# Downloaded: SantoriniGreece33.jpg
# Error downloading https://ts4.mm.bing.net/th?id=OIP.i15cKD3YilRbBw0Ds156sAHaE8&pid=15.1: HTTPSConnectionPool(host='ts4.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Downloaded: SantoriniGreece35.jpg
# Downloaded: SantoriniGreece36.jpg
# Error downloading https://ts2.mm.bing.net/th?id=OIP.m99MCmFkTdAZbc6DQuhs6wHaE8&pid=15.1: HTTPSConnectionPool(host='ts2.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://ts2.mm.bing.net/th?id=OIP.S2813tDRvCPlGWxTEue7FQHaL4&pid=15.1: HTTPSConnectionPool(host='ts2.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Downloaded: SantoriniGreece39.jpg
# Error downloading https://ts2.mm.bing.net/th?id=OIP.W5GqBwNxLZsNKl4hCi8CGgHaE7&pid=15.1: HTTPSConnectionPool(host='ts2.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Downloaded: SantoriniGreece41.jpg
# Error downloading https://ts2.explicit.bing.net/th?id=OIP.H-6RheSIY5EdMkxWOqQpHwHaEo&pid=15.1: HTTPSConnectionPool(host='ts2.explicit.bing.net', port=443): Max retries exceeded with url: /th?id=OIP.H-6RheSIY5EdMkxWOqQpHwHaEo&pid=15.1 (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate in certificate chain (_ssl.c:1000)')))
# Error downloading https://ts2.mm.bing.net/th?id=OIP.lMdQzCg_AuPpd-rW47kEMAHaJQ&pid=15.1: HTTPSConnectionPool(host='ts2.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Downloaded: SantoriniGreece44.jpg
# Error downloading https://ts2.mm.bing.net/th?id=OIP.nMQ4Tu1Xk6iZbGI8NyDwwQHaE8&pid=15.1: HTTPSConnectionPool(host='ts2.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Downloaded: SantoriniGreece46.jpg
# Downloaded: SantoriniGreece47.jpg
# Downloaded: SantoriniGreece48.jpg
# Downloaded: SantoriniGreece49.jpg
# Fetching images for: Grand Canyon USA...
# Downloaded: GrandCanyonUSA0.jpg
# Downloaded: GrandCanyonUSA1.jpg
# Downloaded: GrandCanyonUSA2.jpg
# Downloaded: GrandCanyonUSA3.jpg
# Downloaded: GrandCanyonUSA4.jpg
# Downloaded: GrandCanyonUSA5.jpg
# Downloaded: GrandCanyonUSA6.jpg
# Downloaded: GrandCanyonUSA7.jpg
# Downloaded: GrandCanyonUSA8.jpg
# Downloaded: GrandCanyonUSA9.jpg
# Downloaded: GrandCanyonUSA10.jpg
# Downloaded: GrandCanyonUSA11.jpg
# Downloaded: GrandCanyonUSA12.jpg
# Downloaded: GrandCanyonUSA13.jpg
# Downloaded: GrandCanyonUSA14.jpg
# Downloaded: GrandCanyonUSA15.jpg
# Downloaded: GrandCanyonUSA16.jpg
# Downloaded: GrandCanyonUSA17.jpg
# Downloaded: GrandCanyonUSA18.jpg
# Downloaded: GrandCanyonUSA19.jpg
# Downloaded: GrandCanyonUSA20.jpg
# Downloaded: GrandCanyonUSA21.jpg
# Downloaded: GrandCanyonUSA22.jpg
# Downloaded: GrandCanyonUSA23.jpg
# Error downloading https://ts2.mm.bing.net/th?id=OIP.lkH_JsiY9YyHf4fMqCSH4QHaE9&pid=15.1: HTTPSConnectionPool(host='ts2.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Downloaded: GrandCanyonUSA25.jpg
# Downloaded: GrandCanyonUSA26.jpg
# Error downloading https://ts1.mm.bing.net/th?id=OIP.urnpkFNTfqCfN0Kf9bKsuwHaFi&pid=15.1: HTTPSConnectionPool(host='ts1.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://ts1.mm.bing.net/th?id=OIP.lcwbSveakttYyGJ2psMcOQHaE8&pid=15.1: HTTPSConnectionPool(host='ts1.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Downloaded: GrandCanyonUSA29.jpg
# Downloaded: GrandCanyonUSA30.jpg
# Downloaded: GrandCanyonUSA31.jpg
# Downloaded: GrandCanyonUSA32.jpg
# Downloaded: GrandCanyonUSA33.jpg
# Downloaded: GrandCanyonUSA34.jpg
# Error downloading https://ts1.mm.bing.net/th?id=OIP.5a6_eLnpsIvw0cFtF8nDzwHaHa&pid=15.1: HTTPSConnectionPool(host='ts1.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Downloaded: GrandCanyonUSA36.jpg
# Error downloading https://ts1.mm.bing.net/th?id=OIP.FnnpBs6Fxp0k2bJY2ChB-wHaD4&pid=15.1: HTTPSConnectionPool(host='ts1.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Downloaded: GrandCanyonUSA38.jpg
# Downloaded: GrandCanyonUSA39.jpg
# Downloaded: GrandCanyonUSA40.jpg
# Downloaded: GrandCanyonUSA41.jpg
# Downloaded: GrandCanyonUSA42.jpg
# Downloaded: GrandCanyonUSA43.jpg
# Downloaded: GrandCanyonUSA44.jpg
# Downloaded: GrandCanyonUSA45.jpg
# Error downloading https://ts1.mm.bing.net/th?id=OIP.MDoe1Lg3R8xTvI3bDDOdyAHaGY&pid=15.1: HTTPSConnectionPool(host='ts1.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://ts3.mm.bing.net/th?id=OIP.w2FMU2tmF1tay2ocw41l6wHaFc&pid=15.1: HTTPSConnectionPool(host='ts3.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://ts3.mm.bing.net/th?id=OIP.JA3ibX-YK6a21UumYjdxjgHaE7&pid=15.1: HTTPSConnectionPool(host='ts3.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Downloaded: GrandCanyonUSA49.jpg
# Fetching images for: Mount Fuji Japan...
# Error downloading https://tse3.mm.bing.net/th?q=Mount+Fuji+Temple&w=42&h=42&c=7&rs=1&p=0&o=5&pid=1.7&mkt=en-IN&cc=IN&setlang=en&adlt=moderate&t=1: HTTPSConnectionPool(host='tse3.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://tse1.mm.bing.net/th?q=Mount+Fuji+Climb&w=42&h=42&c=7&rs=1&p=0&o=5&pid=1.7&mkt=en-IN&cc=IN&setlang=en&adlt=moderate&t=1: HTTPSConnectionPool(host='tse1.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://tse3.mm.bing.net/th?q=Mount+Fuji+Elevation&w=42&h=42&c=7&rs=1&p=0&o=5&pid=1.7&mkt=en-IN&cc=IN&setlang=en&adlt=moderate&t=1: HTTPSConnectionPool(host='tse3.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://tse4.mm.bing.net/th?q=Japan+Mount+Fuji+Desktop+Background&w=42&h=42&c=7&rs=1&p=0&o=5&pid=1.7&mkt=en-IN&cc=IN&setlang=en&adlt=moderate&t=1: HTTPSConnectionPool(host='tse4.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://tse3.mm.bing.net/th?q=Mount+Fuji+Winter&w=42&h=42&c=7&rs=1&p=0&o=5&pid=1.7&mkt=en-IN&cc=IN&setlang=en&adlt=moderate&t=1: HTTPSConnectionPool(host='tse3.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://tse4.mm.bing.net/th/id/OIP.OXWg4osFFhrfpyZZ7zH4XwHaEy?w=248&h=180&c=7&r=0&o=5&pid=1.7: HTTPSConnectionPool(host='tse4.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://tse1.mm.bing.net/th/id/OIP.Y2WpBUoV-6J8bFM8cvXEnAHaFj?w=213&h=180&c=7&r=0&o=5&pid=1.7: HTTPSConnectionPool(host='tse1.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://tse2.mm.bing.net/th/id/OIP.sTcafaBZUuLn9HL_a5bYYAHaEP?w=279&h=180&c=7&r=0&o=5&pid=1.7: HTTPSConnectionPool(host='tse2.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://tse4.mm.bing.net/th/id/OIP.thb4fQSnJfe1OGW8TLByVgHaE8?w=240&h=180&c=7&r=0&o=5&pid=1.7: HTTPSConnectionPool(host='tse4.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://tse1.mm.bing.net/th/id/OIP.shPVfRdvuVK2WqI7PTw11wHaE5?w=304&h=200&c=7&r=0&o=5&pid=1.7: HTTPSConnectionPool(host='tse1.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Downloaded: MountFujiJapan10.jpg
# Downloaded: MountFujiJapan11.jpg
# Error downloading https://tse4.mm.bing.net/th/id/OIP.1PoASq62xfHfm3SHujathwHaJ5?w=132&h=180&c=7&r=0&o=5&pid=1.7: HTTPSConnectionPool(host='tse4.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Downloaded: MountFujiJapan13.jpg
# Downloaded: MountFujiJapan14.jpg
# Downloaded: MountFujiJapan15.jpg
# Error downloading https://tse4.mm.bing.net/th/id/OIP.7EeTc60ekkdVedYFDDXeXwHaD1?w=339&h=180&c=7&r=0&o=5&pid=1.7: HTTPSConnectionPool(host='tse4.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Downloaded: MountFujiJapan17.jpg
# Fetching images for: Niagara Falls Canada...
# Downloaded: NiagaraFallsCanada0.jpg
# Downloaded: NiagaraFallsCanada1.jpg
# Error downloading https://tse4.mm.bing.net/th?q=Hotel+Niagara+Falls+Ontario+Canada&w=42&h=42&c=7&rs=1&p=0&o=5&pid=1.7&mkt=en-IN&cc=IN&setlang=en&adlt=moderate&t=1: HTTPSConnectionPool(host='tse4.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://tse4.mm.bing.net/th/id/OIP.JolhyZDykdbdLLIueTpp6wHaE9?w=175&h=180&c=7&r=0&o=5&pid=1.7: HTTPSConnectionPool(host='tse4.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://tse4.mm.bing.net/th/id/OIP.JolhyZDykdbdLLIueTpp6wHaE9?w=89&h=89&c=1&rs=1&qlt=90&r=0&pid=InlineBlock: HTTPSConnectionPool(host='tse4.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://tse4.mm.bing.net/th/id/OIP.IVza7blGEySUciONbFuFEAHaEK?w=89&h=90&c=1&rs=1&qlt=90&r=0&pid=InlineBlock: HTTPSConnectionPool(host='tse4.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://tse4.mm.bing.net/th/id/OIP.3bFWK99kmGhJpHPzTWYEFgHaFn?w=192&h=180&c=7&r=0&o=5&pid=1.7: HTTPSConnectionPool(host='tse4.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://tse4.mm.bing.net/th/id/OIP.IVza7blGEySUciONbFuFEAHaEK?w=258&h=180&c=7&r=0&o=5&pid=1.7: HTTPSConnectionPool(host='tse4.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://tse2.mm.bing.net/th/id/OIP.dJvsmT8AyReAaQ9FpZM8aQHaE7?w=175&h=180&c=7&r=0&o=5&pid=1.7: HTTPSConnectionPool(host='tse2.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://tse3.mm.bing.net/th/id/OIP.n-_HorQFNix2MLUoYOcKqAHaHa?w=89&h=89&c=1&rs=1&qlt=90&r=0&pid=InlineBlock: HTTPSConnectionPool(host='tse3.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://tse1.mm.bing.net/th/id/OIP.ldEhuNCwf1_3c_6xzYH3fwHaHa?w=89&h=90&c=1&rs=1&qlt=90&r=0&pid=InlineBlock: HTTPSConnectionPool(host='tse1.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://tse3.mm.bing.net/th/id/OIP.J8XBxtHjMf75vGq_sFLMVgHaF4?w=251&h=199&c=7&r=0&o=5&pid=1.7: HTTPSConnectionPool(host='tse3.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://tse1.mm.bing.net/th/id/OIP.h_Q-ncUpKGXac1GdwRL9SgHaFj?w=266&h=199&c=7&r=0&o=5&pid=1.7: HTTPSConnectionPool(host='tse1.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://tse4.mm.bing.net/th/id/OIP.IMmD2cS6ZBEyjLTrTcBWpwHaFj?w=65&h=65&c=1&rs=1&qlt=90&r=0&pid=InlineBlock: HTTPSConnectionPool(host='tse4.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://tse2.mm.bing.net/th/id/OIP.8FLQgDxjwJ338L7ROJ619AHaFd?w=65&h=65&c=1&rs=1&qlt=90&r=0&pid=InlineBlock: HTTPSConnectionPool(host='tse2.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://tse2.mm.bing.net/th/id/OIP.5qIRdMiKlmH9noQVV8RYNgHaE-?w=65&h=67&c=1&rs=1&qlt=90&r=0&pid=InlineBlock: HTTPSConnectionPool(host='tse2.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://tse4.mm.bing.net/th/id/OIP.5fwYP_-eFTOqSKch88YPFQHaIN?w=178&h=199&c=7&r=0&o=5&pid=1.7: HTTPSConnectionPool(host='tse4.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://tse4.mm.bing.net/th/id/OIP.-zuknavS-UT-6ouPOlh7qgHaF6?w=251&h=201&c=7&r=0&o=5&pid=1.7: HTTPSConnectionPool(host='tse4.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://tse3.mm.bing.net/th/id/OIP.X90vb8woffJdLzvLbO55BgHaFj?w=66&h=66&c=1&rs=1&qlt=90&r=0&pid=InlineBlock: HTTPSConnectionPool(host='tse3.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Downloaded: NiagaraFallsCanada19.jpg
# Downloaded: NiagaraFallsCanada20.jpg
# Error downloading https://tse2.mm.bing.net/th/id/OIP.5qIRdMiKlmH9noQVV8RYNgHaE-?w=301&h=201&c=7&r=0&o=5&pid=1.7: HTTPSConnectionPool(host='tse2.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Downloaded: NiagaraFallsCanada22.jpg
# Downloaded: NiagaraFallsCanada23.jpg
# Downloaded: NiagaraFallsCanada24.jpg
# Error downloading https://tse3.mm.bing.net/th/id/OIP.rMqxb_wgUWBHqFVEqejF2wHaE8?w=66&h=67&c=1&rs=1&qlt=90&r=0&pid=InlineBlock: HTTPSConnectionPool(host='tse3.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Fetching images for: Pyramids of Giza Egypt...
# Error downloading https://tse2.mm.bing.net/th?q=The+Sphinx+of+Giza&w=42&h=42&c=7&rs=1&p=0&o=5&pid=1.7&mkt=en-IN&cc=IN&setlang=en&adlt=moderate&t=1: HTTPSConnectionPool(host='tse2.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Downloaded: PyramidsofGizaEgypt1.jpg
# Downloaded: PyramidsofGizaEgypt2.jpg
# Downloaded: PyramidsofGizaEgypt3.jpg
# Downloaded: PyramidsofGizaEgypt4.jpg
# Error downloading https://tse1.mm.bing.net/th/id/OIP.YQMTVKDjl3MSqARVFCt5YQHaFj?w=201&h=180&c=7&r=0&o=5&pid=1.7: HTTPSConnectionPool(host='tse1.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Downloaded: PyramidsofGizaEgypt6.jpg
# Downloaded: PyramidsofGizaEgypt7.jpg
# Error downloading https://tse4.mm.bing.net/th/id/OIP.FkEWW_4pc86HSL-NSRT8JAHaEK?w=269&h=180&c=7&r=0&o=5&pid=1.7: HTTPSConnectionPool(host='tse4.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Downloaded: PyramidsofGizaEgypt9.jpg
# Error downloading https://tse1.mm.bing.net/th/id/OIP.dAXYu3Ql-RpJUUPFNFL8agHaE6?w=236&h=180&c=7&r=0&o=5&pid=1.7: HTTPSConnectionPool(host='tse1.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Downloaded: PyramidsofGizaEgypt11.jpg
# Downloaded: PyramidsofGizaEgypt12.jpg
# Downloaded: PyramidsofGizaEgypt13.jpg
# Error downloading https://tse4.mm.bing.net/th/id/OIP.9Fm_ClhWfE-uxSMUNHsvIAHaFD?w=231&h=180&c=7&r=0&o=5&pid=1.7: HTTPSConnectionPool(host='tse4.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Downloaded: PyramidsofGizaEgypt15.jpg
# Error downloading https://ts4.mm.bing.net/th?id=OIP.z2CGUv8FSecHqSEMaimGiwHaEw&pid=15.1: HTTPSConnectionPool(host='ts4.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://ts3.mm.bing.net/th?id=OIP.fEjANMYXOidPybTyyovrOwHaEw&pid=15.1: HTTPSConnectionPool(host='ts3.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://ts3.mm.bing.net/th?id=OIP.JVlWHdrq8uJqYkE_Zo4XjgHaE6&pid=15.1: HTTPSConnectionPool(host='ts3.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Downloaded: PyramidsofGizaEgypt19.jpg
# Error downloading https://ts1.mm.bing.net/th?id=OIP.tocBtQHiioVBZJ-piELQFQHaJ3&pid=15.1: HTTPSConnectionPool(host='ts1.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://ts2.mm.bing.net/th?id=OIP.EU2T9DYxH1Vb-DkeOt-J2AHaCU&pid=15.1: HTTPSConnectionPool(host='ts2.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://ts4.explicit.bing.net/th?id=OIP.ViVCyI7cor7oAXaQYwiu5AHaGF&pid=15.1: HTTPSConnectionPool(host='ts4.explicit.bing.net', port=443): Max retries exceeded with url: /th?id=OIP.ViVCyI7cor7oAXaQYwiu5AHaGF&pid=15.1 (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate in certificate chain (_ssl.c:1000)')))
# Error downloading https://ts2.mm.bing.net/th?id=OIP.1K_zzDSD5JpLH0jNirut2QHaE8&pid=15.1: HTTPSConnectionPool(host='ts2.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://ts1.mm.bing.net/th?id=OIP.yXER0KKoCSdAzG5rx0pQvAHaFj&pid=15.1: HTTPSConnectionPool(host='ts1.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://ts1.mm.bing.net/th?id=OIP.unyHgzzeotXlYE8hz6C3IwHaJQ&pid=15.1: HTTPSConnectionPool(host='ts1.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://ts2.mm.bing.net/th?id=OIP.uFaFzlQ0WOkCWA5ii-87YwHaJ4&pid=15.1: HTTPSConnectionPool(host='ts2.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Downloaded: PyramidsofGizaEgypt27.jpg
# Error downloading https://ts2.mm.bing.net/th?id=OIP.fh4Ho2EW33icxJ4oFsF9jwHaEK&pid=15.1: HTTPSConnectionPool(host='ts2.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Downloaded: PyramidsofGizaEgypt29.jpg
# Downloaded: PyramidsofGizaEgypt30.jpg
# Error downloading https://ts2.mm.bing.net/th?id=OIP.C4qU6h_gLjQsriPsefxjgQHaE8&pid=15.1: HTTPSConnectionPool(host='ts2.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://ts4.explicit.bing.net/th?id=OIP.iainqSPg2S0PvXCQz8q35AHaFj&pid=15.1: HTTPSConnectionPool(host='ts4.explicit.bing.net', port=443): Max retries exceeded with url: /th?id=OIP.iainqSPg2S0PvXCQz8q35AHaFj&pid=15.1 (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate in certificate chain (_ssl.c:1000)')))
# Downloaded: PyramidsofGizaEgypt33.jpg
# Downloaded: PyramidsofGizaEgypt34.jpg
# Downloaded: PyramidsofGizaEgypt35.jpg
# Downloaded: PyramidsofGizaEgypt36.jpg
# Downloaded: PyramidsofGizaEgypt37.jpg
# Downloaded: PyramidsofGizaEgypt38.jpg
# Downloaded: PyramidsofGizaEgypt39.jpg
# Error downloading https://ts2.mm.bing.net/th?id=OIP.uZaq1q18OZxU6sen5pdRQAHaGt&pid=15.1: HTTPSConnectionPool(host='ts2.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Downloaded: PyramidsofGizaEgypt41.jpg
# Downloaded: PyramidsofGizaEgypt42.jpg
# Downloaded: PyramidsofGizaEgypt43.jpg
# Error downloading https://ts2.mm.bing.net/th?id=OIP.n978mq8eR0ZRsqYbaHZB8wHaJ4&pid=15.1: HTTPSConnectionPool(host='ts2.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://ts2.mm.bing.net/th?id=OIP.Cc0itfmj6Zw38uCUAl5a4AHaGN&pid=15.1: HTTPSConnectionPool(host='ts2.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Downloaded: PyramidsofGizaEgypt46.jpg
# Downloaded: PyramidsofGizaEgypt47.jpg
# Error downloading https://ts1.mm.bing.net/th?id=OIP.5UHhN_znm2fMQKnMj3f_cQHaIE&pid=15.1: HTTPSConnectionPool(host='ts1.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://ts1.mm.bing.net/th?id=OIP.6iiFr_Nvfm75VnCB9uGefQHaIi&pid=15.1: HTTPSConnectionPool(host='ts1.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Fetching images for: Petra Jordan...
# Error downloading https://tse1.mm.bing.net/th?q=Petra+Map&w=42&h=42&c=7&rs=1&p=0&o=5&pid=1.7&mkt=en-IN&cc=IN&setlang=en&adlt=moderate&t=1: HTTPSConnectionPool(host='tse1.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://tse4.mm.bing.net/th?q=Petra+Jordan+On+Map&w=42&h=42&c=7&rs=1&p=0&o=5&pid=1.7&mkt=en-IN&cc=IN&setlang=en&adlt=moderate&t=1: HTTPSConnectionPool(host='tse4.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Downloaded: PetraJordan2.jpg
# Downloaded: PetraJordan3.jpg
# Downloaded: PetraJordan4.jpg
# Downloaded: PetraJordan5.jpg
# Downloaded: PetraJordan6.jpg
# Downloaded: PetraJordan7.jpg
# Downloaded: PetraJordan8.jpg
# Downloaded: PetraJordan9.jpg
# Downloaded: PetraJordan10.jpg
# ...
# Downloaded: TimesSquareNewYork4.jpg
# Downloaded: TimesSquareNewYork5.jpg
# Downloaded: TimesSquareNewYork6.jpg
# Downloaded: TimesSquareNewYork7.jpg
# Downloaded: TimesSquareNewYork8.jpg
# Downloaded: TimesSquareNewYork9.jpg
# Downloaded: TimesSquareNewYork10.jpg
# Downloaded: TimesSquareNewYork11.jpg
# Downloaded: TimesSquareNewYork12.jpg
# Error downloading https://tse3.mm.bing.net/th/id/OIP.VWvxcrzjLxfd2XVupvw-5QHaFj?w=89&h=89&c=1&rs=1&qlt=90&r=0&pid=InlineBlock: HTTPSConnectionPool(host='tse3.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://tse3.mm.bing.net/th/id/OIP.uFZpw3LkTnzOr3AFvA9TQQHaFj?w=89&h=90&c=1&rs=1&qlt=90&r=0&pid=InlineBlock: HTTPSConnectionPool(host='tse3.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Downloaded: TimesSquareNewYork15.jpg
# Downloaded: TimesSquareNewYork16.jpg
# Downloaded: TimesSquareNewYork17.jpg
# Downloaded: TimesSquareNewYork18.jpg
# Downloaded: TimesSquareNewYork19.jpg
# Downloaded: TimesSquareNewYork20.jpg
# Error downloading https://ts2.mm.bing.net/th?id=OIP.KcaUjThxe8nAiXq4nFs7ZgHaFS&pid=15.1: HTTPSConnectionPool(host='ts2.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://ts3.mm.bing.net/th?id=OIP._ZlJqeB7sLke0c-4xx0O3QHaEK&pid=15.1: HTTPSConnectionPool(host='ts3.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://ts2.mm.bing.net/th?id=OIP.bd1aBUefUTs2bi4sdQTWaAHaEK&pid=15.1: HTTPSConnectionPool(host='ts2.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Downloaded: TimesSquareNewYork24.jpg
# Error downloading https://ts2.mm.bing.net/th?id=OIP.fIPq805YqV9AruRcjuUinwHaEK&pid=15.1: HTTPSConnectionPool(host='ts2.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Downloaded: TimesSquareNewYork26.jpg
# Downloaded: TimesSquareNewYork27.jpg
# Error downloading https://ts2.mm.bing.net/th?id=OIP.AmvYgdM7R-g8nlxPTGt6ZgHaFj&pid=15.1: HTTPSConnectionPool(host='ts2.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://ts2.mm.bing.net/th?id=OIP.h18G6wLvoLGgbCYakxr36wHaEK&pid=15.1: HTTPSConnectionPool(host='ts2.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://ts2.mm.bing.net/th?id=OIP.yjnrKHNwDIzqNrWtrEubKwHaFL&pid=15.1: HTTPSConnectionPool(host='ts2.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://ts2.mm.bing.net/th?id=OIP.6Xm0FXHziiu5gZ-PcTMc0AHaEK&pid=15.1: HTTPSConnectionPool(host='ts2.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Downloaded: TimesSquareNewYork32.jpg
# Downloaded: TimesSquareNewYork33.jpg
# Downloaded: TimesSquareNewYork34.jpg
# Error downloading https://ts2.mm.bing.net/th?id=OIP.utttYxfNKXk4uF3aeKplFAHaE8&pid=15.1: HTTPSConnectionPool(host='ts2.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Downloaded: TimesSquareNewYork36.jpg
# Error downloading https://ts2.mm.bing.net/th?id=OIP.-UuvX1-aLwfF1n6Z6YTDawHaE4&pid=15.1: HTTPSConnectionPool(host='ts2.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Downloaded: TimesSquareNewYork38.jpg
# Downloaded: TimesSquareNewYork39.jpg
# Downloaded: TimesSquareNewYork40.jpg
# Error downloading https://ts2.mm.bing.net/th?id=OIP.0-3UF17RqZSHce_bFSRXjgHaEx&pid=15.1: HTTPSConnectionPool(host='ts2.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://ts2.mm.bing.net/th?id=OIP.oUZxv4OELs2KHH6CtD6g9AHaJo&pid=15.1: HTTPSConnectionPool(host='ts2.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://ts4.mm.bing.net/th?id=OIP.-bEKlfueR_e_dSN1R42CEAAAAA&pid=15.1: HTTPSConnectionPool(host='ts4.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://ts2.mm.bing.net/th?id=OIP.GMK65Lljgrb3f3Jb4xgtXAHaFU&pid=15.1: HTTPSConnectionPool(host='ts2.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://ts4.mm.bing.net/th?id=OIP.6wVbbgv_BeLcLOgzpLL7AwHaD4&pid=15.1: HTTPSConnectionPool(host='ts4.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://ts1.mm.bing.net/th?id=OIP.EcLcSE5HAiI1O-9xuuS3ZAHaF9&pid=15.1: HTTPSConnectionPool(host='ts1.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://ts3.mm.bing.net/th?id=OIP.Y87obo-B3-viYWJTx-jAAQHaE8&pid=15.1: HTTPSConnectionPool(host='ts3.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://ts2.mm.bing.net/th?id=OIP.iKRzRiuD74MokYFSvCpWuQHaE9&pid=15.1: HTTPSConnectionPool(host='ts2.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://ts2.mm.bing.net/th?id=OIP.yGIugBx8pHDMtjDmbJRELwHaF-&pid=15.1: HTTPSConnectionPool(host='ts2.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Fetching images for: Great Barrier Reef Australia...
# Error downloading https://tse1.mm.bing.net/th?q=Great+Barrier+Reef+Wallpaper&w=42&h=42&c=7&rs=1&p=0&o=5&pid=1.7&mkt=en-IN&cc=IN&setlang=en&adlt=moderate&t=1: HTTPSConnectionPool(host='tse1.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://tse1.mm.bing.net/th?q=Great+Barrier+Reef+Desktop+Wallpaper&w=42&h=42&c=7&rs=1&p=0&o=5&pid=1.7&mkt=en-IN&cc=IN&setlang=en&adlt=moderate&t=1: HTTPSConnectionPool(host='tse1.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Downloaded: GreatBarrierReefAustralia2.jpg
# Error downloading https://tse1.mm.bing.net/th?q=Great+Barrier+Reef+Coral+and+Fish&w=42&h=42&c=7&rs=1&p=0&o=5&pid=1.7&mkt=en-IN&cc=IN&setlang=en&adlt=moderate&t=1: HTTPSConnectionPool(host='tse1.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://tse2.mm.bing.net/th/id/OIP.u7YECChqQVhLNBEhqN7CzAHaE8?w=245&h=180&c=7&r=0&o=5&pid=1.7: HTTPSConnectionPool(host='tse2.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://tse3.mm.bing.net/th/id/OIP.6zrug0AboxiH3EzIxh7j4AHaE8?w=245&h=180&c=7&r=0&o=5&pid=1.7: HTTPSConnectionPool(host='tse3.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Downloaded: GreatBarrierReefAustralia6.jpg
# Downloaded: GreatBarrierReefAustralia7.jpg
# Downloaded: GreatBarrierReefAustralia8.jpg
# Downloaded: GreatBarrierReefAustralia9.jpg
# Downloaded: GreatBarrierReefAustralia10.jpg
# Error downloading https://tse4.mm.bing.net/th/id/OIP.2LfOdeeleEe_FoZFoU2lzAHaER?w=307&h=180&c=7&r=0&o=5&pid=1.7: HTTPSConnectionPool(host='tse4.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Downloaded: GreatBarrierReefAustralia12.jpg
# Downloaded: GreatBarrierReefAustralia13.jpg
# Error downloading https://tse4.mm.bing.net/th/id/OIP.HYi8lFSQLQSdsCWzPQ6LXAAAAA?w=131&h=180&c=7&r=0&o=5&pid=1.7: HTTPSConnectionPool(host='tse4.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Downloaded: GreatBarrierReefAustralia15.jpg
# Error downloading https://ts2.mm.bing.net/th?id=OIP.WmbspoU2Vk6fPAPeddfMxgHaE9&pid=15.1: HTTPSConnectionPool(host='ts2.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Downloaded: GreatBarrierReefAustralia17.jpg
# Downloaded: GreatBarrierReefAustralia18.jpg
# Downloaded: GreatBarrierReefAustralia19.jpg
# Downloaded: GreatBarrierReefAustralia20.jpg
# Downloaded: GreatBarrierReefAustralia21.jpg
# Downloaded: GreatBarrierReefAustralia22.jpg
# Downloaded: GreatBarrierReefAustralia23.jpg
# Downloaded: GreatBarrierReefAustralia24.jpg
# Downloaded: GreatBarrierReefAustralia25.jpg
# Downloaded: GreatBarrierReefAustralia26.jpg
# Downloaded: GreatBarrierReefAustralia27.jpg
# Downloaded: GreatBarrierReefAustralia28.jpg
# Downloaded: GreatBarrierReefAustralia29.jpg
# Downloaded: GreatBarrierReefAustralia30.jpg
# Error downloading https://ts2.mm.bing.net/th?id=OIP.7-RHJC5X0ZrZ-x-fTR6TqgHaFW&pid=15.1: HTTPSConnectionPool(host='ts2.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Downloaded: GreatBarrierReefAustralia32.jpg
# Downloaded: GreatBarrierReefAustralia33.jpg
# Downloaded: GreatBarrierReefAustralia34.jpg
# Downloaded: GreatBarrierReefAustralia35.jpg
# Downloaded: GreatBarrierReefAustralia36.jpg
# Downloaded: GreatBarrierReefAustralia37.jpg
# Downloaded: GreatBarrierReefAustralia38.jpg
# Downloaded: GreatBarrierReefAustralia39.jpg
# Error downloading https://ts2.mm.bing.net/th?id=OIP.d9YNK31p6efOWlV6yFIfzQHaEd&pid=15.1: HTTPSConnectionPool(host='ts2.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Downloaded: GreatBarrierReefAustralia41.jpg
# Error downloading https://ts2.mm.bing.net/th?id=OIP.8J5cWR_vPFh7BO93Go6-jAHaE7&pid=15.1: HTTPSConnectionPool(host='ts2.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Downloaded: GreatBarrierReefAustralia43.jpg
# Downloaded: GreatBarrierReefAustralia44.jpg
# Downloaded: GreatBarrierReefAustralia45.jpg
# Downloaded: GreatBarrierReefAustralia46.jpg
# Downloaded: GreatBarrierReefAustralia47.jpg
# Downloaded: GreatBarrierReefAustralia48.jpg
# Downloaded: GreatBarrierReefAustralia49.jpg
# Fetching images for: Northern Lights Norway...
# Downloaded: NorthernLightsNorway0.jpg
# Downloaded: NorthernLightsNorway1.jpg
# Downloaded: NorthernLightsNorway2.jpg
# Downloaded: NorthernLightsNorway3.jpg
# Downloaded: NorthernLightsNorway4.jpg
# Error downloading https://tse3.mm.bing.net/th/id/OIP.1x4Q8t7mEfozvVsGzvX2EwHaE8?w=175&h=180&c=7&r=0&o=5&pid=1.7: HTTPSConnectionPool(host='tse3.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Downloaded: NorthernLightsNorway6.jpg
# Downloaded: NorthernLightsNorway7.jpg
# Downloaded: NorthernLightsNorway8.jpg
# Downloaded: NorthernLightsNorway9.jpg
# Error downloading https://tse3.mm.bing.net/th/id/OIP.P8VJWhT7aVkK3Tffldf_QQHaEo?w=262&h=180&c=7&r=0&o=5&pid=1.7: HTTPSConnectionPool(host='tse3.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Downloaded: NorthernLightsNorway11.jpg
# Downloaded: NorthernLightsNorway12.jpg
# Error downloading https://tse4.mm.bing.net/th/id/OIP.htela9imeF67sEe_tIw3MwHaDt?w=89&h=89&c=1&rs=1&qlt=90&r=0&pid=InlineBlock: HTTPSConnectionPool(host='tse4.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Downloaded: NorthernLightsNorway14.jpg
# Downloaded: NorthernLightsNorway15.jpg
# Downloaded: NorthernLightsNorway16.jpg
# Downloaded: NorthernLightsNorway17.jpg
# Downloaded: NorthernLightsNorway18.jpg
# Downloaded: NorthernLightsNorway19.jpg
# Downloaded: NorthernLightsNorway20.jpg
# Downloaded: NorthernLightsNorway21.jpg
# Downloaded: NorthernLightsNorway22.jpg
# Downloaded: NorthernLightsNorway23.jpg
# Downloaded: NorthernLightsNorway24.jpg
# Downloaded: NorthernLightsNorway25.jpg
# Downloaded: NorthernLightsNorway26.jpg
# Downloaded: NorthernLightsNorway27.jpg
# Downloaded: NorthernLightsNorway28.jpg
# Downloaded: NorthernLightsNorway29.jpg
# Downloaded: NorthernLightsNorway30.jpg
# Downloaded: NorthernLightsNorway31.jpg
# Downloaded: NorthernLightsNorway32.jpg
# Downloaded: NorthernLightsNorway33.jpg
# Downloaded: NorthernLightsNorway34.jpg
# Downloaded: NorthernLightsNorway35.jpg
# Downloaded: NorthernLightsNorway36.jpg
# Downloaded: NorthernLightsNorway37.jpg
# Downloaded: NorthernLightsNorway38.jpg
# Downloaded: NorthernLightsNorway39.jpg
# Downloaded: NorthernLightsNorway40.jpg
# Downloaded: NorthernLightsNorway41.jpg
# Downloaded: NorthernLightsNorway42.jpg
# Downloaded: NorthernLightsNorway43.jpg
# Downloaded: NorthernLightsNorway44.jpg
# Downloaded: NorthernLightsNorway45.jpg
# Downloaded: NorthernLightsNorway46.jpg
# Downloaded: NorthernLightsNorway47.jpg
# Downloaded: NorthernLightsNorway48.jpg
# Downloaded: NorthernLightsNorway49.jpg
# Fetching images for: Banff National Park Canada...
# Downloaded: BanffNationalParkCanada0.jpg
# Error downloading https://tse3.mm.bing.net/th?q=Banff+National+Park+Stay&w=42&h=42&c=7&rs=1&p=0&o=5&pid=1.7&mkt=en-IN&cc=IN&setlang=en&adlt=moderate&t=1: HTTPSConnectionPool(host='tse3.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Downloaded: BanffNationalParkCanada2.jpg
# Error downloading https://tse3.mm.bing.net/th?q=Banff+National+Park+Facts&w=42&h=42&c=7&rs=1&p=0&o=5&pid=1.7&mkt=en-IN&cc=IN&setlang=en&adlt=moderate&t=1: HTTPSConnectionPool(host='tse3.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Downloaded: BanffNationalParkCanada4.jpg
# Downloaded: BanffNationalParkCanada5.jpg
# Downloaded: BanffNationalParkCanada6.jpg
# Downloaded: BanffNationalParkCanada7.jpg
# Downloaded: BanffNationalParkCanada8.jpg
# Downloaded: BanffNationalParkCanada9.jpg
# Downloaded: BanffNationalParkCanada10.jpg
# Error downloading https://tse3.mm.bing.net/th/id/OIP.YM9b6RZFFeeSUgRp1xlkjwHaEK?w=261&h=180&c=7&r=0&o=5&pid=1.7: HTTPSConnectionPool(host='tse3.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://tse3.mm.bing.net/th/id/OIP.oqNu3Bc2upH8OLtJpu4mQwHaEo?w=89&h=89&c=1&rs=1&qlt=90&r=0&pid=InlineBlock: HTTPSConnectionPool(host='tse3.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://tse3.mm.bing.net/th/id/OIP.CptSoJ4dL39aXiXGHSxvYgHaFj?w=89&h=90&c=1&rs=1&qlt=90&r=0&pid=InlineBlock: HTTPSConnectionPool(host='tse3.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://tse3.mm.bing.net/th/id/OIP.W0qWn0l_KQT1mWVoAARy1QHaFj?w=220&h=180&c=7&r=0&o=5&pid=1.7: HTTPSConnectionPool(host='tse3.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://tse2.mm.bing.net/th/id/OIP.sb33Al165nDqXC3s8JW-TQHaE8?w=241&h=180&c=7&r=0&o=5&pid=1.7: HTTPSConnectionPool(host='tse2.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Error downloading https://tse3.mm.bing.net/th/id/OIP.xiMPF6NRFbcIUniyQUVtQAHaEK?w=286&h=180&c=7&r=0&o=5&pid=1.7: HTTPSConnectionPool(host='tse3.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Downloaded: BanffNationalParkCanada17.jpg
# Error downloading https://tse4.mm.bing.net/th/id/OIP.k8aGrXbtgXs0BKa5YWQKwgHaFj?w=213&h=180&c=7&r=0&o=5&pid=1.7: HTTPSConnectionPool(host='tse4.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Downloaded: BanffNationalParkCanada19.jpg
# Downloaded: BanffNationalParkCanada20.jpg
# Downloaded: BanffNationalParkCanada21.jpg
# Downloaded: BanffNationalParkCanada22.jpg
# Downloaded: BanffNationalParkCanada23.jpg
# Downloaded: BanffNationalParkCanada24.jpg
# Downloaded: BanffNationalParkCanada25.jpg
# Downloaded: BanffNationalParkCanada26.jpg
# Downloaded: BanffNationalParkCanada27.jpg
# Error downloading https://ts4.mm.bing.net/th?id=OIP.BmOQkUOpSzwE0DWxr9057QHaH0&pid=15.1: HTTPSConnectionPool(host='ts4.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Downloaded: BanffNationalParkCanada29.jpg
# Error downloading https://ts4.mm.bing.net/th?id=OIP.j0iy_rz6eorPTzIyEOafogAAAA&pid=15.1: HTTPSConnectionPool(host='ts4.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Downloaded: BanffNationalParkCanada31.jpg
# Downloaded: BanffNationalParkCanada32.jpg
# Error downloading https://ts4.mm.bing.net/th?id=OIP.Be6ZjQIzUMcEbAjs00iy7wHaFu&pid=15.1: HTTPSConnectionPool(host='ts4.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Downloaded: BanffNationalParkCanada34.jpg
# Downloaded: BanffNationalParkCanada35.jpg
# Error downloading https://ts4.mm.bing.net/th?id=OIP.RLmuQhObLVIz378szRYsdwHaHc&pid=15.1: HTTPSConnectionPool(host='ts4.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Downloaded: BanffNationalParkCanada37.jpg
# Downloaded: BanffNationalParkCanada38.jpg
# Downloaded: BanffNationalParkCanada39.jpg
# Downloaded: BanffNationalParkCanada40.jpg
# Downloaded: BanffNationalParkCanada41.jpg
# Downloaded: BanffNationalParkCanada42.jpg
# Error downloading https://ts4.mm.bing.net/th?id=OIP.I69bfoi1thfUj0cazdQRFwHaEo&pid=15.1: HTTPSConnectionPool(host='ts4.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Downloaded: BanffNationalParkCanada44.jpg
# Error downloading https://ts2.mm.bing.net/th?id=OIP.MqjxAg_jOLIvyl_lIQgc5wHaEo&pid=15.1: HTTPSConnectionPool(host='ts2.mm.bing.net', port=443): Read timed out. (read timeout=5)
# Downloaded: BanffNationalParkCanada46.jpg
# Downloaded: BanffNationalParkCanada47.jpg
# Downloaded: BanffNationalParkCanada48.jpg
# Error downloading https://ts3.mm.bing.net/th?id=OIP.e4XlGrlu6pm5hsq6H93WCQHaE8&pid=15.1: HTTPSConnectionPool(host='ts3.mm.bing.net', port=443): Read timed out. (read timeout=5)
# ✅ Image scraping and downloading completed!

# %%
pip install bs4
# Out:
# Collecting bs4
#   Downloading bs4-0.0.2-py2.py3-none-any.whl.metadata (411 bytes)
# Collecting beautifulsoup4 (from bs4)
#   Downloading beautifulsoup4-4.13.3-py3-none-any.whl.metadata (3.8 kB)
# Collecting soupsieve>1.2 (from beautifulsoup4->bs4)
#   Using cached soupsieve-2.6-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\sushmitha\downloads\multimodal\task1\.venv\lib\site-packages (from beautifulsoup4->bs4) (4.12.2)
# Downloading bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Downloading beautifulsoup4-4.13.3-py3-none-any.whl (186 kB)
# Using cached soupsieve-2.6-py3-none-any.whl (36 kB)
# Installing collected packages: soupsieve, beautifulsoup4, bs4
# Successfully installed beautifulsoup4-4.13.3 bs4-0.0.2 soupsieve-2.6
# Note: you may need to restart the kernel to use updated packages.
